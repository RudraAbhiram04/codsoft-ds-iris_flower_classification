# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df=pd.read_csv('/content/IRIS (1).csv')
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates(subset = None, keep='first', inplace=True, ignore_index=False)
df.shape
# Out:
# (147, 5)

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.countplot(x="sepal_length", data=df, hue="species")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x="sepal_width", data=df, hue="species")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x="petal_length", data=df, hue="species")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x="petal_width", data=df, hue="species")
plt.show()

# %%
sns.pairplot(df)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
df['species'].replace(['Iris-setosa','Iris-virginica','Iris-versicolor'],[0,1,2],inplace=True)
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0
# 5           5.4          3.9           1.7          0.4        0
# 6           4.6          3.4           1.4          0.3        0
# 7           5.0          3.4           1.5          0.2        0
# 8           4.4          2.9           1.4          0.2        0
# 9           4.9          3.1           1.5          0.1        0

# %%
from sklearn.model_selection import train_test_split
y=df['species']
x=df.drop(['species'],axis=1)
print(x)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [147 rows x 4 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dtc.predict(x_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 97.2972972972973

# %%
from sklearn import tree
plt.figure(figsize=(12,5))
tree.plot_tree(dtc,feature_names=df.columns)
# Out:
# [Text(0.36363636363636365, 0.9285714285714286, 'petal_width <= 0.8\ngini = 0.666\nsamples = 110\nvalue = [35, 36, 39]'),
#  Text(0.2727272727272727, 0.7857142857142857, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(0.45454545454545453, 0.7857142857142857, 'petal_length <= 4.85\ngini = 0.499\nsamples = 75\nvalue = [0, 36, 39]'),
#  Text(0.18181818181818182, 0.6428571428571429, 'petal_width <= 1.65\ngini = 0.1\nsamples = 38\nvalue = [0, 2, 36]'),
#  Text(0.09090909090909091, 0.5, 'gini = 0.0\nsamples = 35\nvalue = [0, 0, 35]'),
#  Text(0.2727272727272727, 0.5, 'sepal_width <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.18181818181818182, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.36363636363636365, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7272727272727273, 0.6428571428571429, 'petal_width <= 1.75\ngini = 0.149\nsamples = 37\nvalue = [0, 34, 3]'),
#  Text(0.6363636363636364, 0.5, 'sepal_width <= 2.65\ngini = 0.49\nsamples = 7\nvalue = [0, 4, 3]'),
#  Text(0.5454545454545454, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.7272727272727273, 0.35714285714285715, 'petal_length <= 5.05\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.6363636363636364, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8181818181818182, 0.21428571428571427, 'sepal_length <= 6.15\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.7272727272727273, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9090909090909091, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8181818181818182, 0.5, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]')]
